# %%
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Admin\Downloads\country_wise_latest.csv")
print(df)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.tail()
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Country/Region             object
# Confirmed                   int64
# Deaths                      int64
# Recovered                   int64
# Active                      int64
# New cases                   int64
# New deaths                  int64
# New recovered               int64
# Deaths / 100 Cases        float64
# Recovered / 100 Cases     float64
# Deaths / 100 Recovered    float64
# Confirmed last week         int64
# 1 week change               int64
# 1 week % increase         float64
# WHO Region                 object
# dtype: object

# %%
df.shape
# Out:
# (187, 15)

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New cases', 'New deaths', 'New recovered', 'Deaths / 100 Cases',
#        'Recovered / 100 Cases', 'Deaths / 100 Recovered',
#        'Confirmed last week', '1 week change', '1 week % increase',
#        'WHO Region'],
#       dtype='object')

# %%
Q1 = df['Confirmed'].quantile(0.25)
Q3 = df['Confirmed'].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[
    (df['Confirmed'] < lower_limit) |
    (df['Confirmed'] > upper_limit)
]

print(outliers[['Country/Region', 'Confirmed']])
# Out:
#      Country/Region  Confirmed
# 6         Argentina     167416
# 13       Bangladesh     226225
# 23           Brazil    2442375
# 32           Canada     116458
# 35            Chile     347923
# 37         Colombia     257101
# 61           France     220352
# 65          Germany     207112
# 79            India    1480073
# 80        Indonesia     100303
# 81             Iran     293606
# 82             Iraq     112585
# 85            Italy     246286
# 111          Mexico     395489
# 128        Pakistan     274289
# 132            Peru     389717
# 136           Qatar     109597
# 138          Russia     816680
# 145    Saudi Arabia     268934
# 154    South Africa     452529
# 157           Spain     272421
# 172          Turkey     227019
# 173              US    4290259
# 177  United Kingdom     301708

# %%
 df['Country/Region'].nunique()
# Out:
# 187

# %%
df['WHO Region'].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
# KPI

# %%
total_confirmed = df['Confirmed'].sum()
total_deaths = df['Deaths'].sum()
total_recovered = df['Recovered'].sum()
total_active = df['Active'].sum()
total_new_cases = df['New cases'].sum()
total_new_deaths = df['New deaths'].sum()
total_new_recovered = df['New recovered'].sum()

print("Total Confirmed:", total_confirmed)
print("Total Deaths:", total_deaths)
print("Total Recovered:", total_recovered)
print("Total Active:", total_active)
print("Total New Cases:", total_new_cases)
print("Total New Deaths:", total_new_deaths)
print("Total New Recovered:", total_new_recovered)
# Out:
# Total Confirmed: 16480485
# Total Deaths: 654036
# Total Recovered: 9468087
# Total Active: 6358362
# Total New Cases: 228693
# Total New Deaths: 5415
# Total New Recovered: 174623

# %%
# What is the global death rate?

# %%
global_death_rate = (df['Deaths'].sum() / df['Confirmed'].sum()) * 100

print("Global Death Rate:", round(global_death_rate, 2), "%")
# Out:
# Global Death Rate: 3.97 %

# %%
# What is the global recovery rate?

# %%
global_recovery_rate = (df['Recovered'].sum() / df['Confirmed'].sum()) * 100

print("Global Recovery Rate:", round(global_recovery_rate, 2), "%")
# Out:
# Global Recovery Rate: 57.45 %

# %%
# Top 10 Countries by Confirmed Cases

# %%
top_confirmed = df.nlargest(10, 'Confirmed')

top_confirmed[['Country/Region', 'Confirmed']]
# Out:
#      Country/Region  Confirmed
# 173              US    4290259
# 23           Brazil    2442375
# 79            India    1480073
# 138          Russia     816680
# 154    South Africa     452529
# 111          Mexico     395489
# 132            Peru     389717
# 35            Chile     347923
# 177  United Kingdom     301708
# 81             Iran     293606

# %%
# visualization

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_confirmed,
    x='Confirmed',
    y='Country/Region'
)

plt.title("Top 10 Countries by Confirmed COVID-19 Cases")
plt.xlabel("Confirmed Cases")
plt.ylabel("Country")
plt.show()

# %%
#Top 10 Countries by Recoveries
Which countries have the highest recovered cases?

# %%
top_recovered = df.nlargest(10, 'Recovered')

top_recovered[['Country/Region', 'Recovered']]
# Out:
#     Country/Region  Recovered
# 23          Brazil    1846641
# 173             US    1325804
# 79           India     951166
# 138         Russia     602249
# 35           Chile     319954
# 111         Mexico     303810
# 154   South Africa     274925
# 132           Peru     272547
# 81            Iran     255144
# 128       Pakistan     241026

# %%
#visualization

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_recovered,
    x='Recovered',
    y='Country/Region'
)

plt.title("Top 10 Countries by Recovered Cases")
plt.show()

# %%
# Active Cases Analysis
Which countries have the highest active cases?

# %%
top_active = df.nlargest(10, 'Active')

top_active[['Country/Region', 'Active']]
# Out:
#      Country/Region   Active
# 173              US  2816444
# 23           Brazil   508116
# 79            India   495499
# 177  United Kingdom   254427
# 138          Russia   201097
# 154    South Africa   170537
# 37         Colombia   117163
# 61           France   108928
# 32           Canada   107514
# 132            Peru    98752

# %%
# visualization

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_active,
    x='Active',
    y='Country/Region'
)

plt.title("Top 10 Countries by Active Cases")
plt.show()

# %%
# New Cases Analysis
Which countries reported the highest new cases?

# %%
top_new_cases = df.nlargest(10, 'New cases')

top_new_cases[['Country/Region', 'New cases']]
# Out:
#     Country/Region  New cases
# 173             US      56336
# 79           India      44457
# 23          Brazil      23284
# 37        Colombia      16306
# 132           Peru      13756
# 154   South Africa       7096
# 138         Russia       5607
# 111         Mexico       4973
# 6        Argentina       4890
# 13      Bangladesh       2772

# %%
# visualization

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_new_cases,
    x='New cases',
    y='Country/Region'
)

plt.title("Top 10 Countries by New Cases")
plt.show()

# %%
# Weekly Growth Analysis
Which countries experienced the highest weekly increase?

# %%
top_weekly_change = df.nlargest(10, '1 week change')

top_weekly_change[
    ['Country/Region', 'Confirmed last week', 'Confirmed', '1 week change']
]
# Out:
#     Country/Region  Confirmed last week  Confirmed  1 week change
# 173             US              3834677    4290259         455582
# 79           India              1155338    1480073         324735
# 23          Brazil              2118646    2442375         323729
# 154   South Africa               373628     452529          78901
# 37        Colombia               204005     257101          53096
# 111         Mexico               349396     395489          46093
# 138         Russia               776212     816680          40468
# 6        Argentina               130774     167416          36642
# 132           Peru               357681     389717          32036
# 13      Bangladesh               207453     226225          18772

# %%
# Percentage Growth Analysis
Which countries had the highest 1-week percentage increase?

# %%
top_growth = df.nlargest(10, '1 week % increase')

top_growth[
    ['Country/Region', '1 week % increase']
]
# Out:
#        Country/Region  1 week % increase
# 130  Papua New Guinea             226.32
# 63             Gambia             191.07
# 11            Bahamas             119.54
# 186          Zimbabwe              57.85
# 99              Libya              42.78
# 58           Ethiopia              42.52
# 22           Botswana              41.57
# 97            Lesotho              40.67
# 160          Suriname              37.44
# 41         Costa Rica              37.34

# %%
#Visualization

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_growth,
    x='1 week % increase',
    y='Country/Region'
)

plt.title("Top 10 Countries by 1-Week Percentage Increase")
plt.xlabel("1 Week % Increase")
plt.show()

# %%
#WHO Region Analysis
Which WHO region has the highest confirmed cases?

# %%
region_cases = df.groupby('WHO Region')['Confirmed'].sum().sort_values(
    ascending=False
)

region_cases
# Out:
# WHO Region
# Americas                 8839286
# Europe                   3299523
# South-East Asia          1835297
# Eastern Mediterranean    1490744
# Africa                    723207
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %%
# Visualization

# %%
plt.figure(figsize=(12,6))

region_cases.plot(kind='bar')

plt.title("Confirmed Cases by WHO Region")
plt.xlabel("WHO Region")
plt.ylabel("Confirmed Cases")

plt.xticks(rotation=45)
plt.show()

# %%
# Region-wise Death Analysis
Which WHO region has the highest deaths?

# %%
region_deaths = df.groupby('WHO Region')['Deaths'].sum().sort_values(
    ascending=False
)

region_deaths
# Out:
# WHO Region
# Americas                 342732
# Europe                   211144
# South-East Asia           41349
# Eastern Mediterranean     38339
# Africa                    12223
# Western Pacific            8249
# Name: Deaths, dtype: int64

# %%
# visualization

# %%
plt.figure(figsize=(12,6))

region_deaths.plot(kind='bar')

plt.title("Deaths by WHO Region")
plt.ylabel("Deaths")
plt.xticks(rotation=45)

plt.show()

# %%
# Region-wise Recovery Analysis
Which WHO region has the highest recovered cases?

# %%
region_recovered = df.groupby('WHO Region')['Recovered'].sum().sort_values(
    ascending=False
)

region_recovered
# Out:
# WHO Region
# Americas                 4468616
# Europe                   1993723
# Eastern Mediterranean    1201400
# South-East Asia          1156933
# Africa                    440645
# Western Pacific           206770
# Name: Recovered, dtype: int64

# %%
# Region-wise Active Cases
 Which WHO region has the highest active cases?

# %%
region_active = df.groupby('WHO Region')['Active'].sum().sort_values(
    ascending=False
)

region_active
# Out:
# WHO Region
# Americas                 4027938
# Europe                   1094656
# South-East Asia           637015
# Africa                    270339
# Eastern Mediterranean     251005
# Western Pacific            77409
# Name: Active, dtype: int64

# %%
#Regional KPI Table

# %%
region_summary = df.groupby('WHO Region').agg({
    'Confirmed': 'sum',
    'Deaths': 'sum',
    'Recovered': 'sum',
    'Active': 'sum',
    'New cases': 'sum',
    'New deaths': 'sum',
    'New recovered': 'sum'
}).reset_index()

region_summary
# Out:
#               WHO Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0                 Africa     723207   12223     440645   270339      12176
# 1               Americas    8839286  342732    4468616  4027938     129531
# 2  Eastern Mediterranean    1490744   38339    1201400   251005      12410
# 3                 Europe    3299523  211144    1993723  1094656      22294
# 4        South-East Asia    1835297   41349    1156933   637015      48993
# 5        Western Pacific     292428    8249     206770    77409       3289
#
#    New deaths  New recovered
# 0         353          14563
# 1        3555          94776
# 2         445          14843
# 3         304          11732
# 4         734          37582
# 5          24           1127

# %%
# Calculate Regional Death Rate

# %%
region_summary['Death Rate %'] = (
    region_summary['Deaths'] /
    region_summary['Confirmed']) * 100

# Calculate Regional Recovery Rate
region_summary['Recovery Rate %'] = (
    region_summary['Recovered'] /
    region_summary['Confirmed']
) * 100

##
region_summary.sort_values(
    'Death Rate %',
    ascending=False
)
# Out:
#               WHO Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 3                 Europe    3299523  211144    1993723  1094656      22294
# 1               Americas    8839286  342732    4468616  4027938     129531
# 5        Western Pacific     292428    8249     206770    77409       3289
# 2  Eastern Mediterranean    1490744   38339    1201400   251005      12410
# 4        South-East Asia    1835297   41349    1156933   637015      48993
# 0                 Africa     723207   12223     440645   270339      12176
#
#    New deaths  New recovered  Death Rate %  Recovery Rate %
# 3         304          11732      6.399228        60.424583
# 1        3555          94776      3.877372        50.554038
# 5          24           1127      2.820865        70.708003
# 2         445          14843      2.571803        80.590631
# 4         734          37582      2.252987        63.037917
# 0         353          14563      1.690111        60.929305

# %%
# Highest Mortality Rate
Which countries have the highest deaths per 100 cases?

# %%
highest_mortality = df.nlargest(
    10,
    'Deaths / 100 Cases'
)

highest_mortality[
    ['Country/Region', 'Confirmed', 'Deaths',
     'Deaths / 100 Cases']
]
# Out:
#      Country/Region  Confirmed  Deaths  Deaths / 100 Cases
# 184           Yemen       1691     483               28.56
# 177  United Kingdom     301708   45844               15.19
# 16          Belgium      66428    9822               14.79
# 85            Italy     246286   35112               14.26
# 61           France     220352   30212               13.71
# 77          Hungary       4448     596               13.40
# 120     Netherlands      53413    6160               11.53
# 111          Mexico     395489   44022               11.13
# 157           Spain     272421   28432               10.44
# 183  Western Sahara         10       1               10.00

# %%
# Highest Recovery Rate
 Which countries have the highest recovery percentage?

# %%
highest_recovery = df.nlargest(
    10,
    'Recovered / 100 Cases'
)

highest_recovery[
    ['Country/Region',
     'Confirmed',
     'Recovered',
     'Recovered / 100 Cases']
]
# Out:
#     Country/Region  Confirmed  Recovered  Recovered / 100 Cases
# 49        Dominica         18         18                 100.00
# 69         Grenada         23         23                 100.00
# 75        Holy See         12         12                 100.00
# 48        Djibouti       5059       4977                  98.38
# 78         Iceland       1854       1823                  98.33
# 24          Brunei        141        138                  97.87
# 121    New Zealand       1557       1514                  97.24
# 136          Qatar     109597     106328                  97.02
# 105       Malaysia       8904       8601                  96.60
# 110      Mauritius        344        332                  96.51

# %%
# Lowest Recovery Rate
Which countries have the lowest recovery rate?

# %%
lowest_recovery = df.nsmallest(
    10,
    'Recovered / 100 Cases'
)

lowest_recovery[
    ['Country/Region',
     'Recovered / 100 Cases']
]
# Out:
#      Country/Region  Recovered / 100 Cases
# 32           Canada                   0.00
# 117      Mozambique                   0.00
# 147          Serbia                   0.00
# 161          Sweden                   0.00
# 163           Syria                   0.00
# 168     Timor-Leste                   0.00
# 120     Netherlands                   0.35
# 177  United Kingdom                   0.48
# 118         Namibia                   5.48
# 22         Botswana                   8.53

# %%
# Highest Deaths per 100 Recovered
Q21. Which countries have the highest deaths relative to recoveries?

# %%
df.nlargest(
    10,
    'Deaths / 100 Recovered'
)[
    ['Country/Region',
     'Deaths / 100 Recovered']
]
# Out:
#      Country/Region  Deaths / 100 Recovered
# 32           Canada                     inf
# 117      Mozambique                     inf
# 147          Serbia                     inf
# 161          Sweden                     inf
# 163           Syria                     inf
# 120     Netherlands                 3259.26
# 177  United Kingdom                 3190.26
# 184           Yemen                   57.98
# 16          Belgium                   56.28
# 61           France                   37.20

# %%
Country with Maximum New Deaths
 Which countries reported the highest new deaths?

# %%
df.nlargest(
    10,
    'New deaths'
)[
    ['Country/Region', 'New deaths']
]
# Out:
#     Country/Region  New deaths
# 173             US        1076
# 79           India         637
# 23          Brazil         614
# 132           Peru         575
# 37        Colombia         508
# 111         Mexico         342
# 154   South Africa         298
# 81            Iran         212
# 6        Argentina         120
# 82            Iraq          96

# %%
# Country with Maximum New Recoveries
. Which countries reported the highest new recoveries?

# %%
df.nlargest(
    10,
    'New recovered'
)[
    ['Country/Region', 'New recovered']
]
# Out:
#     Country/Region  New recovered
# 23          Brazil          33728
# 79           India          33598
# 173             US          27941
# 37        Colombia          11494
# 154   South Africa           9848
# 111         Mexico           8588
# 132           Peru           4697
# 128       Pakistan           3592
# 138         Russia           3077
# 145   Saudi Arabia           2613

# %%
# Countries With Zero New Cases
 Which countries reported zero new cases?

# %%
zero_new_cases = df[df['New cases'] == 0]

zero_new_cases[
    ['Country/Region', 'Confirmed', 'New cases']
]
# Out:
#                        Country/Region  Confirmed  New cases
# 14                           Barbados        110          0
# 17                             Belize         48          0
# 18                              Benin       1770          0
# 24                             Brunei        141          0
# 27                              Burma        350          0
# 33           Central African Republic       4599          0
# 38                            Comoros        354          0
# 49                           Dominica         18          0
# 54                  Equatorial Guinea       3071          0
# 56                            Estonia       2034          0
# 59                               Fiji         27          0
# 69                            Grenada         23          0
# 72                      Guinea-Bissau       1954          0
# 75                           Holy See         12          0
# 94                               Laos         20          0
# ...

# %%
# Countries With Zero Deaths
Which countries reported zero deaths?

# %%
zero_deaths = df[df['Deaths'] == 0]

zero_deaths[
    ['Country/Region', 'Confirmed', 'Deaths']
]
# Out:
#                        Country/Region  Confirmed  Deaths
# 19                             Bhutan         99       0
# 30                           Cambodia        226       0
# 49                           Dominica         18       0
# 55                            Eritrea        265       0
# 59                               Fiji         27       0
# 68                          Greenland         14       0
# 69                            Grenada         23       0
# 75                           Holy See         12       0
# 94                               Laos         20       0
# 114                          Mongolia        289       0
# 130                  Papua New Guinea         62       0
# 140             Saint Kitts and Nevis         17       0
# 141                       Saint Lucia         24       0
# 142  Saint Vincent and the Grenadines         52       0
# 148                        Seychelles        114       0
# ...

# %%
# Countries With Zero Recoveries
Which countries reported zero recovered cases?

# %%
zero_recovered = df[df['Recovered'] == 0]

zero_recovered[
    ['Country/Region', 'Confirmed', 'Recovered']
]
# Out:
#     Country/Region  Confirmed  Recovered
# 32          Canada     116458          0
# 117     Mozambique       1701          0
# 147         Serbia      24141          0
# 161         Sweden      79395          0
# 163          Syria        674          0
# 168    Timor-Leste         24          0

# %%
# Active Case Percentage
Create a new column:

# %%
df['Active %'] = (
    df['Active'] / df['Confirmed']
) * 100

# # Which countries have the highest percentage of active cases?
df.nlargest(
    10,
    'Active %'
)[
    ['Country/Region', 'Confirmed', 'Active', 'Active %']
]
# Out:
#     Country/Region  Confirmed  Active    Active %
# 168    Timor-Leste         24      24  100.000000
# 117     Mozambique       1701    1690   99.353322
# 147         Serbia      24141   23598   97.750715
# 118        Namibia       1843    1734   94.085730
# 163          Syria        674     634   94.065282
# 161         Sweden      79395   73695   92.820707
# 32          Canada     116458  107514   92.319978
# 22        Botswana        739     674   91.204330
# 120    Netherlands      53413   47064   88.113381
# 76        Honduras      39741   33536   84.386402

# %%
# Correlation Analysis - This is for EDA

# %%
# What is the relationship between confirmed cases and deaths?
df[['Confirmed', 'Deaths']].corr()
# Heatmap
plt.figure(figsize=(12,8))

numeric_cols = [
    'Confirmed',
    'Deaths',
    'Recovered',
    'Active',
    'New cases',
    'New deaths',
    'New recovered',
    'Deaths / 100 Cases',
    'Recovered / 100 Cases',
    'Deaths / 100 Recovered',
    'Confirmed last week',
    '1 week change',
    '1 week % increase'
]

sns.heatmap(
    df[numeric_cols].corr(),
    annot=True,
    cmap='coolwarm',
    fmt='.2f'
)

plt.title("Correlation Matrix")
plt.show()

# %%
# Confirmed Cases vs Deaths

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x='Confirmed',
    y='Deaths'
)

plt.title("Confirmed Cases vs Deaths")
plt.xlabel("Confirmed Cases")
plt.ylabel("Deaths")

plt.show()

# %%
# Confirmed Cases vs Recoveries

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x='Confirmed',
    y='Recovered'
)

plt.title("Confirmed Cases vs Recovered Cases")
plt.show()

# %%
# Active Cases vs Confirmed Cases

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x='Confirmed',
    y='Active'
)

plt.title("Confirmed Cases vs Active Cases")
plt.show()

# %%
# Distribution of Confirmed Cases
How are confirmed cases distributed?

plt.figure(figsize=(10,6))

sns.histplot(
    data=df,
    x='Confirmed',
    bins=30,
    kde=True
)

plt.title("Distribution of Confirmed Cases")
plt.show()

##  COVID cases are highly skewed,

plt.figure(figsize=(10,6))

sns.histplot(
    np.log1p(df['Confirmed']),
    bins=30,
    kde=True
)

plt.title("Log Distribution of Confirmed Cases")
plt.show()
# Out:
# Object `distributed` not found.

# %%
# Boxplot & Outlier Analysis
Are there outliers in numerical variables?

# %%
numerical_cols = [
    'Confirmed',
    'Deaths',
    'Recovered',
    'Active',
    'New cases',
    'New deaths',
    'New recovered',
    'Deaths / 100 Cases',
    'Recovered / 100 Cases',
    'Deaths / 100 Recovered',
    'Confirmed last week',
    '1 week change',
    '1 week % increase'
]

## 
for col in numerical_cols:
    plt.figure(figsize=(8,4))
    sns.boxplot(data=df, x=col)
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# IQR Method for Outliers

def detect_outliers(data, column):
    
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = data[
        (data[column] < lower_bound) |
        (data[column] > upper_bound)
    ]
    
    return outliers, lower_bound, upper_bound

    ##
    outliers_confirmed, lower, upper = detect_outliers(
    df,
    'Confirmed'
)

print("Lower Bound:", lower)
print("Upper Bound:", upper)

outliers_confirmed[
    ['Country/Region', 'Confirmed']
]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 26
#      20     ##
#      21     outliers_confirmed, lower, upper = detect_outliers(
#      22     df,
#      23     'Confirmed'
#      24 )
# ---> 26 print("Lower Bound:", lower)
#      27 print("Upper Bound:", upper)
#      29 outliers_confirmed[
#      30     ['Country/Region', 'Confirmed']
#      31 ]
#
# NameError: name 'lower' is not defined

# %%
# Find the Most Affected Countries

df['Impact Score'] = (
    df['Confirmed'] +
    df['Deaths'] +
    df['Active']
)
##
df.nlargest(
    10,
    'Impact Score'
)[
    ['Country/Region',
     'Confirmed',
     'Deaths',
     'Active',
     'Impact Score']
]
# Out:
#      Country/Region  Confirmed  Deaths   Active  Impact Score
# 173              US    4290259  148011  2816444       7254714
# 23           Brazil    2442375   87618   508116       3038109
# 79            India    1480073   33408   495499       2008980
# 138          Russia     816680   13334   201097       1031111
# 154    South Africa     452529    7067   170537        630133
# 177  United Kingdom     301708   45844   254427        601979
# 132            Peru     389717   18418    98752        506887
# 111          Mexico     395489   44022    47657        487168
# 157           Spain     272421   28432    93613        394466
# 37         Colombia     257101    8777   117163        383041

# %%
# Compare Current vs Previous Week

# %%
df['Weekly Growth'] = (
    df['Confirmed'] -
    df['Confirmed last week']
)
# verify against existing columns
(df['Weekly Growth'] == df['1 week change']).value_counts()
# Out:
# True    187
# Name: count, dtype: int64

# %%
# Top Countries With Rapid Growth

# %%
rapid_growth = df.sort_values(
    '1 week % increase',
    ascending=False
)

rapid_growth[
    ['Country/Region',
     'Confirmed',
     'Confirmed last week',
     '1 week change',
     '1 week % increase']
].head(15)
# Out:
#        Country/Region  Confirmed  Confirmed last week  1 week change  \
# 130  Papua New Guinea         62                   19             43
# 63             Gambia        326                  112            214
# 11            Bahamas        382                  174            208
# 186          Zimbabwe       2704                 1713            991
# 99              Libya       2827                 1980            847
# 58           Ethiopia      14547                10207           4340
# 22           Botswana        739                  522            217
# 97            Lesotho        505                  359            146
# 160          Suriname       1483                 1079            404
# 41         Costa Rica      15841                11534           4307
# 118           Namibia       1843                 1344            499
# 185            Zambia       4552                 3326           1226
# 103        Madagascar       9690                 7153           2537
# ...

# %%
# Country-Level KPI Function

# %%
def country_analysis(country):

    result = df[df['Country/Region'] == country]
    
    if result.empty:
        print("Country not found")
        return
    
    display(
        result[
            [
                'Country/Region',
                'Confirmed',
                'Deaths',
                'Recovered',
                'Active',
                'New cases',
                'New deaths',
                'New recovered',
                'Deaths / 100 Cases',
                'Recovered / 100 Cases',
                '1 week % increase',
                'WHO Region'
            ]
        ]
    )
##
country_analysis("India")
##
country_analysis("Americas")
# Out:
#    Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 79          India    1480073   33408     951166  495499      44457
#
#     New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79         637          33598                2.26                  64.26
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia
# Country not found

# %%
# WHO Region Country Count
 How many countries are present in each WHO region?

# %%
country_count = df.groupby(
    'WHO Region'
)['Country/Region'].count().sort_values(
    ascending=False
)

country_count

## Visualization:
plt.figure(figsize=(10,6))

country_count.plot(kind='bar')

plt.title("Number of Countries by WHO Region")
plt.ylabel("Number of Countries")
plt.xticks(rotation=45)

plt.show()

# %%
#  Region-Level Average Recovery Rate

# %%
region_avg_recovery = df.groupby(
    'WHO Region'
)['Recovered / 100 Cases'].mean().sort_values(
    ascending=False
)

region_avg_recovery
# Out:
# WHO Region
# Western Pacific          76.805000
# Europe                   68.635000
# South-East Asia          66.704000
# Eastern Mediterranean    66.593182
# Americas                 62.291429
# Africa                   57.014792
# Name: Recovered / 100 Cases, dtype: float64

# %%
# Region-Level Average Death Rate

# %%
region_avg_death = df.groupby(
    'WHO Region'
)['Deaths / 100 Cases'].mean().sort_values(
    ascending=False
)

region_avg_death
# Out:
# WHO Region
# Europe                   4.198393
# Eastern Mediterranean    3.563182
# Americas                 3.052571
# Africa                   2.306458
# South-East Asia          1.296000
# Western Pacific          1.290000
# Name: Deaths / 100 Cases, dtype: float64

# %%
# Best Recovery Performance

# %%
best_recovery_region = region_avg_recovery.idxmax()
best_recovery_value = region_avg_recovery.max()

print(
    best_recovery_region,
    round(best_recovery_value, 2)
)
# Out:
# Western Pacific 76.8

# %%
# Highest Death Rate Region

# %%
highest_death_region = region_avg_death.idxmax()
highest_death_value = region_avg_death.max()

print(
    highest_death_region,
    round(highest_death_value, 2)
)
# Out:
# Europe 4.2

# %%
# Create Final Dashboard Dataset

# %%
dashboard_df = df[
    [
        'Country/Region',
        'WHO Region',
        'Confirmed',
        'Deaths',
        'Recovered',
        'Active',
        'New cases',
        'New deaths',
        'New recovered',
        'Deaths / 100 Cases',
        'Recovered / 100 Cases',
        'Confirmed last week',
        '1 week change',
        '1 week % increase'
    ]
]

dashboard_df.head()
##
 dashboard_df.to_csv(
    'COVID19_cleaned_dashboard.csv',
    index=False
)
# Out:
#   Cell In[78], line 22
#     dashboard_df.to_csv(
#     ^
# IndentationError: unexpected indent

# %%
## Key Business/Analytical Insights

Insight 1

Americas was the most affected WHO region, accounting for the highest confirmed cases, deaths, and active cases in the dataset.

Insight 2

The US had the highest confirmed cases and absolute deaths, making it the largest country-level contributor to the overall case burden.

Insight 3

India showed significant weekly growth, with more than 324K additional confirmed cases and a 28.11% weekly increase.

Insight 4

High percentage growth was concentrated among several countries with relatively small case counts, so percentage growth should be interpreted alongside absolute case numbers.

Insight 5

Yemen had the highest recorded death rate, but its absolute number of deaths was much lower than countries such as the US and Brazil.

Insight 6

Confirmed cases and deaths have a strong positive relationship, indicating that countries with larger case burdens generally also experienced higher absolute deaths.

Insight 7

The Americas had approximately 4.03M active cases, highlighting a substantial ongoing burden at the dataset's snapshot.

Insight 8

Recovery performance varied considerably across countries and regions, suggesting differences in the stage and severity of outbreaks represented in the data.

# %%
# For India
India Showed Strong Weekly Growth

India had:

1,480,073 confirmed cases
33,408 deaths
951,166 recovered
495,499 active
324,735 one-week increase
28.11% one-week percentage increase

Interpretation:
India's 28.11% weekly growth indicates rapid expansion in confirmed cases during the period represented by the dataset. Although its absolute case count was lower than the US, its relative weekly growth was considerably higher.
